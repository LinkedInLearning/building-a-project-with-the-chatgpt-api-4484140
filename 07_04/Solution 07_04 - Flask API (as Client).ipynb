# %% [markdown]
# # Building a Project with the ChatGPT API

# %% [markdown]
# ## Flask REST API in Jupyter runs as a Client

# %% [markdown]
# ## Post Tweet using the Twitter API
#
# ### This is the extra portion of the hands-on challenge to turn the code into a REST API using Flask. This notebook acts as the client used to test the API.

# %%
import requests

# %%
response = requests.get('http://127.0.0.1:5000/tweets?service=sagemaker')
response.text
# Out:
# 'Tweet sent!'

# %% [markdown]
# ### Screenshot of tweet that was sent

# %% [markdown]
# ![Screen%20Shot%202023-06-03%20at%2012.51.13%20PM.png](attachment:Screen%20Shot%202023-06-03%20at%2012.51.13%20PM.png)
